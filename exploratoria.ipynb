# %%
import pandas as pd
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
input_file = '../microdados_enem_2023/DADOS/MICRODADOS_ENEM_2023.csv'
# input_file ='microdados_tratado.csv'
df = pd.read_csv(input_file, sep=';', encoding='ISO-8859-1')

df.to_parquet('microdados_enem_2023.parquet', index=False)

# df = pd.read_parquet('microdados_enem_2023.parquet')

# dtypes = pd.read_json("dtypes.json", typ='series')
# df = df.astype(dtypes)

# %%
f = df.select_dtypes(include='float16').columns
i = df.select_dtypes(include='int16').columns

df[f] = df[f].astype('float64')
df[i] = df[i].astype('int64')

# %%
# df2 = df.sample(1000000, random_state=42)

# %%
# df.shape

# %%
# df.info(memory_usage='deep')

# %%
profile = ProfileReport(df, title="Analise microdados")
profile.to_file("exploratoria_original.html")
# Out:
# ...
# 100%|██████████| 76/76 [04:47<00:00,  3.78s/it]
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 profile = ProfileReport(df, title="Analise microdados")
# ----> 2 profile.to_file("exploratoria_original.html")
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\profile_report.py:381, in ProfileReport.to_file(self, output_file, silent)
# ...
