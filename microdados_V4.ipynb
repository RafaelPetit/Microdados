# %%
"""
Este programa faz analise inicial dos dados do ENEM 2023

Funcionalidades:
- Levantando as seguintes questões:
1. Perfil socio econômico dos candidatos
    1.1 Criação de Índices socioeconômicos
        -Comparação Regional: Quais regiões do país possuem os índices mais altos e mais baixos?
        -Distribuição de Classes: Quantos participantes se encontram em cada classe socioeconômica definida (e.g., baixa, média, alta)?
        -Relação com Desempenho Acadêmico: Estudantes com maiores índices socioeconômicos têm melhor desempenho no ENEM?
    1.2 Segmentação por grupos Socioseconômicos
        -Percentual de cada grupo em diferentes regiões do país.
        -Quais bens ou serviços são mais predominantes em cada grupo?

    1.3 Relação Escola x Renda
        -Descubra se há um "ponto crítico" na escolaridade (por exemplo, ensino médio completo) que proporciona uma mudança significativa na renda.
        -Compare como a relação entre escolaridade e renda varia entre gêneros ou regiões.

    1.4 Ocupação e sua hierarquia
        -Verifique se há discrepâncias entre o nível de escolaridade dos pais e suas ocupações (exemplo: pessoas com ensino superior em ocupações informais).
        -Analise se há diferenças de ocupação entre mães e pais, e como isso impacta o índice socioeconômico.    

    1.5 Relação entre Infraestrtura Domicilar e Nível Socioeconômico
        -Estudantes com maior acesso à infraestrutura tecnológica (computador, internet) têm melhor desempenho acadêmico?
        -Qual a infraestrutura média por região e como ela se relaciona com o índice socioeconômico?
    

- Analisara as respostas dos candidatos do ENEM 2023 para as questões q01 a q04, q06 a q025
    Q001: Até que série seu pai, ou o homem responsável por você, estudou?
    Q002: Até que série sua mãe, ou a mulher responsável por você, estudou?
    Q003: A partir da apresentação de quais documentos você conseguiu concluir o ensino médio?
    Q004: A partir da apresentação de quais documentos você conseguiu concluir ou concluirá o ensino médio?
    Q006: Qual é a renda mensal de sua família? (Some a sua renda com a dos seus familiares.)
    Q007: Em sua residência tem banheiro?
    Q008: Em sua residência tem quartos para dormir?
    Q009: Em sua residência tem carro?
    Q010: Em sua residência tem motocicleta?
    Q011: Em sua residência tem geladeira?
    Q012: Em sua residência tem freezer (independente ou segunda porta da geladeira)?
    Q013: Em sua residência tem máquina de lavar roupa?
    Q014: Em sua residência tem máquina de secar roupa?
    Q015: Em sua residência tem forno micro-ondas?
    Q016: Em sua residência tem máquina de lavar louça?
    Q017: Em sua residência tem aspirador de pó?
    Q018: Em sua residência tem televisão em cores?
    Q019: Em sua residência tem aparelho de DVD?
    Q020: Em sua residência tem TV por assinatura?
    Q021: Em sua residência tem telefone celular?
    Q022: Em sua residência tem telefone fixo?
    Q023: Em sua residência tem computador?
    Q024: Em sua residência tem acesso à Internet?
    Q025: Em sua residência tem serviço de banda larga (internet fixa)?



- faz a leitura dos dados do ENEM 2023 limpos no programa 01_enem_2023.ipynb
- cria os seguintes dicionarios para mapear os dados:
    - faixa etária: coluna TP_FAIXA_ETARIA
    - sexo: coluna TP_SEXO
    - estado civil: coluna TP_ESTADO_CIVIL
    - cor/raça: coluna TP_COR_RACA
    - nacionalidade: coluna TP_NACIONALIDADE
    - situação de conclusão do ensino médio: coluna TP_SITUACAO_CONCLUSAO
    - ano de conclusão do ensino médio: coluna TP_ANO_CONCLUIU
    - tipo de escola do ensino médio: coluna TP_ESCOLA
    - tipo de instiuição que concluiu ou concluirá o EM: coluna TP_ENSINO
    - candidato é treineiro: coluna IN_TREINEIRO
    - dependência administrativa da escola: coluna TP_DEPENDENCIA_ADM_ESC
    - localização da escola: coluna TP_LOCALIZACAO_ESC
    - sigla da UF da escola: coluna SG_UF_PROVA

- para cada dicionário foi plotado um histograma para visualização dos dados

"""
# Out:
# '\nEste programa faz analise inicial dos dados do ENEM 2023\n\nFuncionalidades:\n- Levantando as seguintes questões:\n1. Perfil socio econômico dos candidatos\n    1.1 Criação de Índices socioeconômicos\n        -Comparação Regional: Quais regiões do país possuem os índices mais altos e mais baixos?\n        -Distribuição de Classes: Quantos participantes se encontram em cada classe socioeconômica definida (e.g., baixa, média, alta)?\n        -Relação com Desempenho Acadêmico: Estudantes com maiores índices socioeconômicos têm melhor desempenho no ENEM?\n    1.2 Segmentação por grupos Socioseconômicos\n        -Percentual de cada grupo em diferentes regiões do país.\n        -Quais bens ou serviços são mais predominantes em cada grupo?\n\n    1.3 Relação Escola x Renda\n        -Descubra se há um "ponto crítico" na escolaridade (por exemplo, ensino médio completo) que proporciona uma mudança significativa na renda.\n        -Compare como a relação entre escolaridade e renda varia entre gêneros ou regiões.\n\n    1.4 Ocupação e sua hierarquia\n        -Verifique se há discrepâncias entre o nível de escolaridade dos pais e suas ocupações (exemplo: pessoas com ensino superior em ocupações informais).\n        -Analise se há diferenças de ocupação entre mães e pais, e como isso impacta o índice socioeconômico.    \n\n    1.5 Relação entre Infraestrtura Domicilar e Nível Socioeconômico\n        -Estudantes com maior acesso à infraestrutura tecnológica (computador, internet) têm melhor desempenho acadêmico?\n        -Qual a infraestrutura média por região e como ela se relaciona com o índice socioeconômico?\n    \n\n- Analisara as respostas dos candidatos do ENEM 2023 para as questões q01 a q04, q06 a q025\n    Q001: Até que série seu pai, ou o homem responsável por você, estudou?\n    Q002: Até que série sua mãe, ou a mulher responsável por você, estudou?\n    Q003: A partir da apresentação de quais documentos você conseguiu concluir o ensino médio?\n    Q004: A partir da apresentação de quais documentos você conseguiu concluir ou concluirá o ensino médio?\n    Q006: Qual é a renda mensal de sua família? (Some a sua renda com a dos seus familiares.)\n    Q007: Em sua residência tem banheiro?\n    Q008: Em sua residência tem quartos para dormir?\n    Q009: Em sua residência tem carro?\n    Q010: Em sua residência tem motocicleta?\n    Q011: Em sua residência tem geladeira?\n    Q012: Em sua residência tem freezer (independente ou segunda porta da geladeira)?\n    Q013: Em sua residência tem máquina de lavar roupa?\n    Q014: Em sua residência tem máquina de secar roupa?\n    Q015: Em sua residência tem forno micro-ondas?\n    Q016: Em sua residência tem máquina de lavar louça?\n    Q017: Em sua residência tem aspirador de pó?\n    Q018: Em sua residência tem televisão em cores?\n    Q019: Em sua residência tem aparelho de DVD?\n    Q020: Em sua residência tem TV por assinatura?\n    Q021: Em sua residência tem telefone celular?\n    Q022: Em sua residência tem telefone fixo?\n    Q023: Em sua residência tem computador?\n    Q024: Em sua residência tem acesso à Internet?\n    Q025: Em sua residência tem serviço de banda larga (internet fixa)?\n\n\n\n- faz a leitura dos dados do ENEM 2023 limpos no programa 01_enem_2023.ipynb\n- cria os seguintes dicionarios para mapear os dados:\n    - faixa etária: coluna TP_FAIXA_ETARIA\n    - sexo: coluna TP_SEXO\n    - estado civil: coluna TP_ESTADO_CIVIL\n    - cor/raça: coluna TP_COR_RACA\n    - nacionalidade: coluna TP_NACIONALIDADE\n    - situação de conclusão do ensino médio: coluna TP_SITUACAO_CONCLUSAO\n    - ano de conclusão do ensino médio: coluna TP_ANO_CONCLUIU\n    - tipo de escola do ensino médio: coluna TP_ESCOLA\n    - tipo de instiuição que concluiu ou concluirá o EM: coluna TP_ENSINO\n    - candidato é treineiro: coluna IN_TREINEIRO\n    - dependência administrativa da escola: coluna TP_DEPENDENCIA_ADM_ESC\n    - localização da escola: coluna TP_LOCALIZACAO_ESC\n    - sigla da UF ...

# %%
# Criando um dicionário para mapear os valores da coluna 'TP_FAIXA_ETARIA'
faixa_etaria = {
    1: '< 17',
    2: '17',
    3: '18',
    4: '19',
    5: '20',
    6: '21',
    7: '22',
    8: '23',
    9: '24',
    10: '25',
    11: '26 < 30',
    12: '31 < 35',
    13: '36 < 40',
    14: '41 < 45',
    15: '46 < 50',
    16: '51 < 55',
    17: '56 < 60',
    18: '61 < 65',
    19: '66 < 70',
    20: '> 70'
}


# Criando um dicionário para mapear os valores da coluna 'TP_SEXO'
sexo = {
    'F': 'Feminino',
    'M': 'Masculino',
}

# Criando um dicionário para mapear os valores da coluna 'TP_ESTADO_CIVIL'
estado_civil = {
    0: 'Não informado',
    1: 'Solteiro(a)',
    2: 'Casado(a)/Mora com companheiro(a)',
    3: 'Divorciado(a)/Desquitado(a)/Separado(a)',
    4: 'Viúvo(a)'
}

# Criando um dicionário para mapear os valores da coluna 'TP_COR_RACA'
cor_raca = {
    0: 'Não declarado',
    1: 'Branca',
    2: 'Preta',
    3: 'Parda',
    4: 'Amarela',
    5: 'Indígena',
    6: 'Não dispõe da informação'
}

# Criando um dicionário para mapear os valores da coluna 'TP_NACIONALIDADE'
nacionalidade = {
    0: 'Não informado',
    1: 'Brasileiro(a)',
    2: 'Brasileiro(a) Naturalizado(a)',
    3: 'Estrangeiro(a)',
    4: 'Brasileiro(a) Nato(a), nascido(a) no exterior'
}

# Criando um dicionário para mapear os valores da coluna 'TP_ST_CONCLUSAO'
st_conclusao = {
    1: 'Já concluí o Ensino Médio',
    2: 'Estou cursando e concluirei o Ensino Médio em 2023',
    3: 'Estou cursando e concluirei o Ensino Médio após 2023',
    4: 'Não concluí e não estou cursando o Ensino Médio'
}

# Criando um dicionário para mapear os valores da coluna 'TP_ANO_CONCLUIU'
ano_concluiu = {
    0: 'Não informado',
    1: '2022',
    2: '2021',
    3: '2020',
    4: '2019',
    5: '2018',
    6: '2017',
    7: '2016',
    8: '2015',
    9: '2014',
    10: '2013',
    11: '2012',
    12: '2011',
    13: '2010',
    14: '2009',
    15: '2008',
    16: '2007',
    17: '< 2007'
}

# Criando um dicionário para mapear os valores da coluna 'TP_ESCOLA'
escola = {
    1: 'Não Respondeu',
    2: 'Pública',
    3: 'Privada'
}

# Criando um dicionário para mapear os valores da coluna 'TP_ENSINO'
ensino = {
    -1: 'Desconhecido', # Este valor foi adicionado manualmente. NÃO ESTA PREVISTO NO DATASET ORIGINAL
    1: 'Regular',
    2: 'Educação Especial - Modalidade Substitutiva'
}

# Criando um dicionário para mapear os valores da coluna 'IN_TREINEIRO'
treineiro = {
    0: 'Não',
    1: 'Sim'
}

# Criando um dicionário para mapear os valores da coluna 'TP_DEPENDENCIA_ADM_ESC'
dependencia_adm_esc = {
    -1: 'Desconhecido', # Este valor foi adicionado manualmente. NÃO ESTA PREVISTO NO DATASET ORIGINAL
    1: 'Federal',
    2: 'Estadual',
    3: 'Municipal',
    4: 'Privada'
}

# Criando um dicionário para mapear os valores da coluna 'TP_LOCALIZACAO_ESC'
localizacao_esc = {
    -1: 'Desconhecido', # Este valor foi adicionado manualmente. NÃO ESTA PREVISTO NO DATASET ORIGINAL
    1: 'Urbana',
    2: 'Rural'
}

# Criando um dicionário para mapear os estados do Brasil
uf_brasil = {
    'AC': 'Acre',
    'AL': 'Alagoas',
    'AP': 'Amapá',
    'AM': 'Amazonas',
    'BA': 'Bahia',
    'CE': 'Ceará',
    'DF': 'Distrito Federal',
    'ES': 'Espírito Santo',
    'GO': 'Goiás',
    'MA': 'Maranhão',
    'MT': 'Mato Grosso',
    'MS': 'Mato Grosso do Sul',
    'MG': 'Minas Gerais',
    'PA': 'Pará',
    'PB': 'Paraíba',
    'PR': 'Paraná',
    'PE': 'Pernambuco',
    'PI': 'Piauí',
    'RJ': 'Rio de Janeiro',
    'RN': 'Rio Grande do Norte',
    'RS': 'Rio Grande do Sul',
    'RO': 'Rondônia',
    'RR': 'Roraima',
    'SC': 'Santa Catarina',
    'SP': 'São Paulo',
    'SE': 'Sergipe',
    'TO': 'Tocantins',
    'Desconhecido': 'Desconhecido' # Este valor foi adicionado manualmente. NÃO ESTA PREVISTO NO DATASET ORIGINAL
}

# %%
# Criando dicionário para mapear as respostas da Q1 a Q5

# Criando um dicionário para mapear os valores da coluna 'Q1': Até que série seu pai, ou o homem responsável por você, estudou?

q001 = {
    'A': 'Nunca estudou',
    'B': '< 5º ano do EF',
    'C': '< 9º ano do EF',
    'D': 'EM I',
    'E': '< SU I',
    'F': 'SU C e PG I',	
    'G': 'PG C',
    'H': 'Não sei'
}

'''
    'A': 'Nunca estudou',
    'B': 'Não completou a 4ª série/5º ano do Ensino Fundamental',
    'C': 'Completou a 4ª série/5º ano, mas não completou a 8ª série/9º ano do Ensino Fundamental',
    'D': 'Completou a 8ª série/9º ano do Ensino Fundamental, mas não completou o Ensino Médio',
    'E': 'Completou o Ensino Médio, mas não completou a Faculdade',
    'F': 'Completou a Faculdade, mas não completou a Pós-graduação',
    'G': 'Completou a Pós-graduação',
    'H': 'Não sei'
'''
# A questão Q2 é igual a Q1 mas se refere a mãe

# Criando um dicionário para mapear os valores da coluna 'Q3': A partir da apresentação de algumas ocupações divididas em grupos ordenados, indique o grupo que contempla a ocupação mais próxima da ocupação do seu pai ou do homem responsável por você. (Se ele não estiver trabalhando, escolha uma ocupação pensando no último trabalho dele).
q3 = {
    'A': 'Grupo 1',
    'B': 'Grupo 2',
    'C': 'Grupo 3',
    'D': 'Grupo 4',
    'E': 'Grupo 5',
    'F': 'Não sei',
}

'''
Grupo 1: Lavrador, agricultor sem empregados, bóia fria, criador de animais (gado, porcos, galinhas, ovelhas, cavalos etc.), apicultor, pescador, lenhador, seringueiro, extrativista.
Grupo 2: Diarista, empregado doméstico, cuidador de idosos, babá, cozinheiro (em casas particulares), motorista particular, jardineiro, faxineiro de empresas e prédios, vigilante, porteiro, carteiro, office-boy, vendedor, caixa, atendente de loja, auxiliar administrativo, recepcionista, servente de pedreiro, repositor de mercadoria.
Grupo 3: Padeiro, cozinheiro industrial ou em restaurantes, sapateiro, costureiro, joalheiro, torneiro mecânico, operador de máquinas, soldador, operário de fábrica, trabalhador da mineração, pedreiro, pintor, eletricista, encanador, motorista, caminhoneiro, taxista.
Grupo 4: Professor (de ensino fundamental ou médio, idioma, música, artes etc.), técnico (de enfermagem, contabilidade, eletrônica etc.), policial, militar de baixa patente (soldado, cabo, sargento), corretor de imóveis, supervisor, gerente, mestre de obras, pastor, microempresário (proprietário de empresa com menos de 10 empregados), pequeno comerciante, pequeno proprietário de terras, trabalhador autônomo ou por conta própria.
Grupo 5: Médico, engenheiro, dentista, psicólogo, economista, advogado, juiz, promotor, defensor, delegado, tenente, capitão, coronel, professor universitário, diretor em empresas públicas ou privadas, político, proprietário de empresas com mais de 10 empregados.
'''

# A questão Q4 é igual a Q3 mas se refere a mãe

# A questão Q5 é um valor numérico, não é necessário criar um dicionário

# Criando um dicionário para mapear os valores da coluna 'Q006': Qual é a renda mensal de sua família? (Some a sua renda com a dos seus familiares.)
q6 = {
    'A': 'Nenhuma',
    'B': 'Até 1 SM',
    'C': '1 - 1.5 SM',
    'D': '1.5 - 2 SM',
    'E': '2 - 2.5 SM',
    'F': '2.5 - 3 SM',
    'G': '3 - 4 SM',
    'H': '4 - 5 SM',
    'I': '5 - 6 SM',
    'J': '6 - 7 SM',
    'K': '7 - 8 SM',
    'L': '8 - 9 SM',
    'M': '9 - 10 SM',
    'N': '10 - 12 SM',
    'O': '12 - 15 SM',
    'P': '15 - 20 SM',
    'Q': '> 20 SM'
}
"""
A: Nenhuma - Sem rendimento mensal.
B: Até 1 SM - Rendimento mensal de até 1 Salário Mínimo.
C: 1 - 1.5 SM - Rendimento mensal entre 1 e 1.5 Salários Mínimos.
D: 1.5 - 2 SM - Rendimento mensal entre 1.5 e 2 Salários Mínimos.
E: 2 - 2.5 SM - Rendimento mensal entre 2 e 2.5 Salários Mínimos.
F: 2.5 - 3 SM - Rendimento mensal entre 2.5 e 3 Salários Mínimos.
G: 3 - 4 SM - Rendimento mensal entre 3 e 4 Salários Mínimos.
H: 4 - 5 SM - Rendimento mensal entre 4 e 5 Salários Mínimos.
I: 5 - 6 SM - Rendimento mensal entre 5 e 6 Salários Mínimos.
J: 6 - 7 SM - Rendimento mensal entre 6 e 7 Salários Mínimos.
K: 7 - 8 SM - Rendimento mensal entre 7 e 8 Salários Mínimos.
L: 8 - 9 SM - Rendimento mensal entre 8 e 9 Salários Mínimos.
M: 9 - 10 SM - Rendimento mensal entre 9 e 10 Salários Mínimos.
N: 10 - 12 SM - Rendimento mensal entre 10 e 12 Salários Mínimos.
O: 12 - 15 SM - Rendimento mensal entre 12 e 15 Salários Mínimos.
P: 15 - 20 SM - Rendimento mensal entre 15 e 20 Salários Mínimos.
Q: > 20 SM - Rendimento mensal superior a 20 Salários Mínimos.
"""

# Criando um dicionário para mapear os valores da coluna 'Q007': Em sua residência trabalha empregado(a) doméstico(a)?
q7 = {
    'A': 0,
    'B': 1,
    'C': 2,
    'D': 3,
    'E': 4
}

"""
A: Não.
B: sim, um ou dois dias por semana.
C: sim, dois ou três dias por semana.
D: sim, três ou quatro dias por semana.
E: quatro ou mais dias por semana.
"""

# Criando um dicionário para mapear os valores da coluna 'Q008': Na sua residência, tem banheiro?
q7_q19 = {
    'A': 0,
    'B': 1,
    'C': 2,
    'D': 3,
    'E': 4
}
"""
    'A': 'Não',
    'B': 'Sim, um',
    'C': 'Sim, dois',
    'D': 'Sim, três',
    'E': 'Sim, quatro ou mais'
"""
# - Colunas Q007 á Q0017, 'Q019', 'Q022', 'Q024'  tem o mesmo padrão de respostas, então será necessario criar um dicionário para mapear os valores de cada coluna

# Criando um dicionário para mapear os valores da coluna 'Q018', 'Q020', Q021', 'Q023' e 'Q025'
q18_q25 = {
    'A': 0,
    'B': 1
}

presenca_geral = {
    0: 'Faltou às prova',
    1: 'Presente nas provas',
}

# Criando um dicionário para mapear os valores da coluna NU_DESEMPENHO
desempenho = {
    1: 'Alto',
    2: 'Médio',
    3: 'Baixo',
    4: 'Muito Baixo'
}

infraestrutura = {
    1: 'Infraestrutura alta',
    2: 'Infraestrutura média',
    3: 'Infraestrutura baixa',
}

# Lista para ordenar as barras do gráfico de barras de acordo com a coluna infraestrutra
order_hue_infra = ['Alto', 'Médio', 'Baixo']

# Lista para ordenar as barras do gráfico de barras de acordo com a coluna desempenho
order_hue_desempenho = ['Alto', 'Médio', 'Baixo', 'Muito Baixo']

# %%
# Importando as bibliotecas necessárias
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# %%
microdados = pd.read_csv('microdados_tratado_copia.csv', sep=';', encoding='ISO-8859-1')

"""
Leitura do arquivo JSON com os tipos de dados de cada coluna
Atualizar o arquivo JSON com os tipos de dados corretos e otimizados
"""
dtypes = pd.read_json("dtypes.json", typ='series')
microdados = microdados.astype(dtypes)

microdados = microdados.sample(10000, random_state=42)

# %%
colunas_infraestrutura = ['Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025']

microdados[colunas_infraestrutura] = microdados[colunas_infraestrutura].astype('string')

# %%
# """
#     Plota um histograma de contagem com opcionalmente uma legenda (hue),
#     forçando ordem fixa de categorias na legenda.
# """

# def plot_histograma(df, coluna_x, coluna_hue, 
#                                    dicionario_x=None, dicionario_hue=None, order_hue=None,
#                                    titulo='', rotacao_xticks=0, rotacao_xticks_barra=0,
#                                    text_size=12, pad_titulo=20, palette='Set2', ):
    
#     plt.figure(figsize=(10, 8))
#     ax = sns.countplot(data=df, x=coluna_x, hue=coluna_hue, palette=palette)

#     # Adicionar valores no topo das barras
#     for p in ax.patches:
#         height = p.get_height()
#         ax.text(p.get_x() + p.get_width()/2.0,
#                 height + 15,
#                 int(height),
#                 ha="center",
#                 rotation=rotacao_xticks_barra,
#                 size=text_size)

#     # Aplicar mapeamento aos rótulos do eixo x, se fornecido
#     if dicionario_x:
#         # Pega as labels que já estão no eixo x
#         current_labels = [tick.get_text() for tick in ax.get_xticklabels()]
#         # Mapeia cada label
#         new_labels = [dicionario_x.get(lbl, lbl) for lbl in current_labels]
#         ax.set_xticklabels(new_labels)

#     # Se tivermos dicionário para o HUE, mapeia para a ordem desejada
#     if dicionario_hue:
#         # Pega as "handles" e "labels" atuais da legenda
#         handles, raw_labels = ax.get_legend_handles_labels()

#         # Mapeia cada label bruto do DataFrame (por exemplo 0,1,2) para o rótulo amigável (Alto, Médio, Baixo)
#         mapped_labels = [dicionario_hue.get(lbl, str(lbl)) for lbl in raw_labels]

#         # Define a ordem na legenda:
#         labels_order = order_hue

#         # Cria um dicionário {rótulo_mapeado: handle}
#         label_to_handle = dict(zip(mapped_labels, handles))

#         # Filtra e reordena conforme a lista 'labels_order', considerando só os que existem de fato
#         final_labels = [lab for lab in labels_order if lab in label_to_handle]
#         final_handles = [label_to_handle[lab] for lab in final_labels]

#         # Define a legenda com a ordem e rótulos desejados
#         ax.legend(final_handles, final_labels, title=coluna_hue.replace('_', ' ').title(), loc='upper right')
#     else:
#         ax.legend(title=coluna_hue.replace('_', ' ').title(), loc='upper right')

#     plt.title(titulo, pad=pad_titulo)
#     plt.xlabel(coluna_x.replace('_', ' ').title())
#     plt.ylabel('Quantidade')
#     plt.xticks(rotation=rotacao_xticks)
#     plt.tight_layout()
#     plt.show()

# %%
"""
Com os clusters definidos e as categorias atribuídas, podemos realizar análises mais aprofundadas sobre
a infraestrutura domiciliar dos candidatos do ENEM 2023.
1. Distribuição dos clusters por faixa etária, sexo e cor/raça.
2. Relação entre infraestrutura e desempenho.
3. Comparação regional dos clusters.
4. Associação entre infraestrutura e renda familiar.
5. Impacto da infraestrutura na taxa de abandono escolar.
6. Infraestrutura e Nivel de Escolaridade dos Responsáveis
"""
# Out:
# '\nCom os clusters definidos e as categorias atribuídas, podemos realizar análises mais aprofundadas sobre\na infraestrutura domiciliar dos candidatos do ENEM 2023.\n1. Distribuição dos clusters por faixa etária, sexo e cor/raça.\n2. Relação entre infraestrutura e desempenho.\n3. Comparação regional dos clusters.\n4. Associação entre infraestrutura e renda familiar.\n5. Impacto da infraestrutura na taxa de abandono escolar.\n6. Infraestrutura e Nivel de Escolaridade dos Responsáveis\n'

# %%
# def plot_histograma(df, coluna_x, coluna_hue, 
#                                    dicionario_x=None, dicionario_hue=None, order_hue=None,
#                                    titulo='', rotacao_xticks=0, rotacao_xticks_barra=0,
#                                    text_size=12, ):
#     """
#     Plota um histograma de contagem com opcionalmente uma legenda (hue),
#     forçando ordem fixa de categorias na legenda.
#     """
#     plt.figure(figsize=(10, 8))
#     ax = sns.countplot(data=df, x=coluna_x, hue=coluna_hue, palette='Set2')

#     # Adicionar valores no topo das barras
#     for p in ax.patches:
#         height = p.get_height()
#         ax.text(p.get_x() + p.get_width()/2.0,
#                 height + 15,
#                 int(height),
#                 ha="center",
#                 rotation=rotacao_xticks_barra,
#                 size=text_size)

#     # Aplicar mapeamento aos rótulos do eixo x, se fornecido
#     if dicionario_x:
#         # Pegamos as labels que já estão no eixo x
#         current_labels = [tick.get_text() for tick in ax.get_xticklabels()]
#         # Mapeamos cada label
#         new_labels = [dicionario_x.get(lbl, lbl) for lbl in current_labels]
#         ax.set_xticklabels(new_labels)

#     # Se tivermos dicionário para o HUE, mapeamos para a ordem desejada
#     if dicionario_hue:
#         # Pega as "handles" e "labels" atuais da legenda
#         handles, raw_labels = ax.get_legend_handles_labels()

#         # Mapeia cada label bruto do DataFrame (por exemplo 0,1,2) para o rótulo amigável (Alto, Médio, Baixo)
#         mapped_labels = [dicionario_hue.get(lbl, str(lbl)) for lbl in raw_labels]

#         # Define a ordem que você QUER na legenda:
#         labels_order = order_hue

#         # Cria um dicionário {rótulo_mapeado: handle}
#         label_to_handle = dict(zip(mapped_labels, handles))

#         # Filtra e reordena conforme a lista 'labels_order', considerando só os que existem de fato
#         final_labels = [lab for lab in labels_order if lab in label_to_handle]
#         final_handles = [label_to_handle[lab] for lab in final_labels]

#         # Define a legenda com a ordem e rótulos desejados
#         ax.legend(final_handles, final_labels, title=coluna_hue.replace('_', ' ').title(), loc='upper right')
#     else:
#         ax.legend(title=coluna_hue.replace('_', ' ').title(), loc='upper right')

#     plt.title(titulo, pad=20)
#     plt.xlabel(coluna_x.replace('_', ' ').title())
#     plt.ylabel('Quantidade')
#     plt.xticks(rotation=rotacao_xticks)
#     plt.tight_layout()
#     plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plotar_histograma(
    df,
    coluna_x,
    coluna_hue,
    dicionario_x=None,
    dicionario_hue=None,
    ordem_x=None,
    ordem_hue=None,
    titulo='',
    rotacao_xticks=0,
    rotacao_xticks_barra=0,
    tamanho_texto=12,
    paleta_cores='Set2'
):
    """
    Plota um histograma de contagem (countplot) usando Seaborn, com controle de
    ordem e mapeamento de rótulos (labels) através de dicionários.

    Parâmetros
    ----------
    df : pd.DataFrame
        DataFrame contendo os dados que serão plotados.

    coluna_x : str
        Nome da coluna (no DataFrame) que será usada no eixo X.

    coluna_hue : str
        Nome da coluna (no DataFrame) que será usada como hue (categoria que
        divide as barras).

    dicionario_x : dict, opcional
        Mapeamento {valor_no_df: rótulo_desejado} para substituir os rótulos
        que aparecem no eixo X.

    dicionario_hue : dict, opcional
        Mapeamento {valor_no_df: rótulo_desejado} para substituir os rótulos
        na legenda (hue).

    ordem_x : list, opcional
        Lista que determina a ordem das categorias no eixo X.
        Se None e existir dicionario_x, a ordem assumirá as chaves de dicionario_x.
        Caso contrário, usará a ordem natural (unique()) dos dados.

    ordem_hue : list, opcional
        Lista que determina a ordem das categorias na legenda (hue).
        Se None e existir dicionario_hue, a ordem assumirá as chaves de dicionario_hue.
        Caso contrário, usará a ordem natural (unique()) dos dados.

    titulo : str, opcional
        Título do gráfico.

    rotacao_xticks : float, opcional
        Ângulo de rotação dos rótulos no eixo X (ticks).

    rotacao_xticks_barra : float, opcional
        Ângulo de rotação do texto que fica no topo de cada barra,
        indicando o valor de contagem.

    tamanho_texto : int, opcional
        Tamanho da fonte para o texto no topo das barras.

    paleta_cores : str ou list, opcional
        Paleta de cores Seaborn (ex.: 'Set2', 'viridis' ou uma lista de cores).
    """

    # Determinar a ordem do eixo X
    if ordem_x is None:
        if dicionario_x is not None:
            ordem_x = list(dicionario_x.keys())
        else:
            ordem_x = df[coluna_x].dropna().unique().tolist()

    # Determinar a ordem do hue
    if ordem_hue is None:
        if dicionario_hue is not None:
            ordem_hue = list(dicionario_hue.keys())
        else:
            ordem_hue = df[coluna_hue].dropna().unique().tolist()

    # Configurar tamanho da figura e DPI
    plt.figure(figsize=(10, 8), dpi=80)

    # Criar o gráfico de contagem
    ax = sns.countplot(
        data=df,
        x=coluna_x,
        hue=coluna_hue,
        palette=paleta_cores,
        order=ordem_x,
        hue_order=ordem_hue
    )

    # Adicionar valores no topo de cada barra
    for barra in ax.patches:
        altura = barra.get_height()
        if altura > 0:
            ax.text(
                barra.get_x() + barra.get_width() / 2.0,
                altura + 1,  # deslocamento fixo
                int(altura),
                ha="center",
                rotation=rotacao_xticks_barra,
                size=tamanho_texto
            )

    # Ajustar rótulos (labels) do eixo X com base no dicionario_x
    if dicionario_x:
        novos_rotulos_x = [dicionario_x.get(cat, str(cat)) for cat in ordem_x]
        ax.set_xticklabels(novos_rotulos_x)

    # Ajustar a legenda (hue) com base no dicionario_hue
    if dicionario_hue:
        # Obter 'handles' e 'labels' da legenda criada pelo Seaborn
        handles, labels = ax.get_legend_handles_labels()
        novos_rotulos_hue = []
        for rotulo in labels:
            try:
                # Tenta converter o rótulo para inteiro
                rotulo_int = int(rotulo)
                novo_rotulo = dicionario_hue.get(rotulo_int, rotulo)
            except ValueError:
                # Se não for possível converter, pode ser string
                novo_rotulo = dicionario_hue.get(rotulo, rotulo)
            novos_rotulos_hue.append(novo_rotulo)

        ax.legend(handles, novos_rotulos_hue,
                  title=coluna_hue.replace('_', ' ').title(),
                  loc='upper right')
    else:
        ax.legend(title=coluna_hue.replace('_', ' ').title(), loc='upper right')

    # Título, labels e ajustes finais
    plt.title(titulo, pad=20)
    plt.xlabel(coluna_x.replace('_', ' ').title())
    plt.ylabel('Quantidade')
    plt.xticks(rotation=rotacao_xticks)

    # Ajustar layout para não cortar nada (se causar problemas de dimensão, comente)
    plt.tight_layout()

    # Exibir gráfico
    plt.show()

# %%
microdados['NU_INFRAESTRUTURA'].head()
# Out:
# 553635     3
# 3349365    1
# 2297393    2
# 1082491    2
# 1894282    3
# Name: NU_INFRAESTRUTURA, dtype: category
# Categories (3, int64): [1, 2, 3]

# %%
# Distribuição dos Infraestrutura por Faixa Etária
plotar_histograma(
    df=microdados,
    coluna_x='TP_FAIXA_ETARIA',
    coluna_hue='NU_INFRAESTRUTURA',
    dicionario_x=faixa_etaria,            
    dicionario_hue=infraestrutura,  
    titulo='Distribuição de infrastrutura por Faixa Etária',
    rotacao_xticks=45,
    rotacao_xticks_barra=90,
    tamanho_texto=8,
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6004\1456845440.py:112: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(novos_rotulos_x)

# %%
# Plotando Desempenho por Faixa Etária
plotar_histograma(
    df=microdados,
    coluna_x='TP_FAIXA_ETARIA',
    coluna_hue='NU_DESEMPENHO',
    dicionario_x=faixa_etaria,            
    dicionario_hue=desempenho,  
    titulo='Distribuição de Desempenho por Faixa Etária',
    rotacao_xticks=45,
    rotacao_xticks_barra=45,
    tamanho_texto=7,
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6004\1456845440.py:112: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(novos_rotulos_x)

# %%
microdados['TP_SEXO'].value_counts()
# Out:
# TP_SEXO
# F    6124
# M    3876
# Name: count, dtype: int64

# %%
# Distribuição dos Infraestrutura por Sexo
plotar_histograma(
    df=microdados,
    coluna_x='TP_SEXO',
    coluna_hue='NU_INFRAESTRUTURA',
    dicionario_x=sexo,                   
    dicionario_hue=infraestrutura,
    titulo='Distribuição dos Infraestrutura por Sexo',
    rotacao_xticks=0,
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6004\1456845440.py:112: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(novos_rotulos_x)

# %%
# Plotando Desempenho por Sexo

plotar_histograma(
    df=microdados,
    coluna_x='TP_SEXO',
    coluna_hue='NU_DESEMPENHO',
    dicionario_x=sexo,            
    dicionario_hue=desempenho,      
    titulo='Distribuição de Desempenho por Sexo',
    rotacao_xticks=45,
    rotacao_xticks_barra=45,
    tamanho_texto=7,
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6004\1456845440.py:112: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(novos_rotulos_x)

# %%
# Distribuição dos Infraestrutura por Cor/Raça
plot_histograma(
    df=microdados,
    coluna_x='TP_COR_RACA',
    coluna_hue='categoria_infraestrutura',
    dicionario_x=cor_raca,               # Mapeamento para rótulos do eixo x
    dicionario_hue=infra,      
    order_hue=order_hue_infra,         # Caso queira renomear as categorias dos clusters, forneça aqui
    titulo='Distribuição dos Infraestrutura por Cor/Raça',
    rotacao_xticks=45,
    pad_titulo=20,
    palette='Set2'
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8676\10489152.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)

# %%
# Plotando Dempenho por Cor/Raça
plot_histograma(
    df=microdados,
    coluna_x='TP_COR_RACA',
    coluna_hue='NU_DESEMPENHO',
    dicionario_x=cor_raca,               # Mapeamento para rótulos do eixo x
    dicionario_hue=desempenho,
    order_hue=order_hue_desempenho,           # Mapeamento para rótulos da legenda
    titulo='Distribuição de Desempenho por Cor/Raça',
    rotacao_xticks=45,
    pad_titulo=20,
    palette='Set2'
)

# %%
# Distribuição dos Infraestrutura por Categoria de Desempenho
plot_histograma(
    df=microdados,
    coluna_x='NU_DESEMPENHO',
    coluna_hue='categoria_infraestrutura',
    dicionario_x=desempenho,             # Mapeamento para rótulos do eixo x
    dicionario_hue=infra,       
              order_hue=order_hue_infra,          # Caso queira renomear as categorias dos clusters, forneça aqui
    titulo='Distribuição dos Infraestrutura por Categoria de Desempenho',
    rotacao_xticks=0,
    pad_titulo=20,
    palette='Set2'
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16296\2306014749.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)

# %%
# 3. Comparação regional dos clusters.
plot_histograma(
    df=microdados,
    coluna_x='SG_UF_PROVA',
    coluna_hue='categoria_infraestrutura',
    dicionario_x=uf_brasil,               # Mapeamento para rótulos do eixo x
    dicionario_hue=infra,
           order_hue=order_hue_infra,       # Caso queira renomear as categorias dos clusters, forneça aqui
    titulo='Distribuição dos Infraestrutura por Estado',
    rotacao_xticks=90,
    rotacao_xticks_barra=90,
    text_size=8,
    pad_titulo=20,
    palette='Set2'
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13192\10489152.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)

# %%
# Plotandp Comparação de Desempenho por Estado
plot_histograma(
    df=microdados,
    coluna_x='SG_UF_PROVA',
    coluna_hue='NU_DESEMPENHO',
    dicionario_x=uf_brasil,               # Mapeamento para rótulos do eixo x
    dicionario_hue=desempenho,
                order_hue=order_hue_desempenho,            # Mapeamento para rótulos da legenda
    titulo='Distribuição de Desempenho por Estado',
    rotacao_xticks=90,
    rotacao_xticks_barra=90,
    text_size=8,
    pad_titulo=20,
    palette='Set2'
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8676\10489152.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)

# %%
# Plotando Impacto da infraestrutura na taxa de abandono escolar.
plot_histograma(
    df=microdados,
    coluna_x='TP_ST_CONCLUSAO',
    coluna_hue='categoria_infraestrutura',
    dicionario_x=st_conclusao,            # Mapeamento para rótulos do eixo x
    dicionario_hue=infra,
                      order_hue=order_hue_infra,                  # Não precisa mapear novamente
    titulo='Distribuição dos Infraestrutura por Situação de Conclusão do Ensino Médio',
    rotacao_xticks=90,
    pad_titulo=20,
    palette='Set2'
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13192\10489152.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)

# %%
# Infraestrutura por quantidade de candidatos
categoria_counts = microdados['categoria_infraestrutura'].value_counts()
categoria_counts.plot(kind='bar', color='skyblue')
plt.title('Quantidade de Candidatos por Infraestrutura')
plt.xlabel('Categoria de Infraestrutura')
plt.xticks(rotation=90)
plt.show()

# %%
# Plotando Infraestrutura e Nivel de Escolaridade dos Pai
plot_histograma(
    df=microdados,
    coluna_x='Q001',
    coluna_hue='categoria_infraestrutura',
    dicionario_x=q001,                      # Mapeamento para rótulos do eixo x
    dicionario_hue=infra,  
                    order_hue=order_hue_infra,                # Não precisa mapear novamente
    titulo='Distribuição dos Infraestrutura por Nível de Escolaridade do Pai',
    rotacao_xticks=45,
    pad_titulo=20,
    palette='Set2'
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13192\10489152.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)

# %%
# Plotando Desempenho por escolaridade do Pai
plot_histograma(
    df=microdados,
    coluna_x='Q001',
    coluna_hue='NU_DESEMPENHO',
    dicionario_x=q001,                      # Mapeamento para rótulos do eixo x
    dicionario_hue=desempenho,  
              order_hue=order_hue_desempenho,          # Mapeamento para rótulos da legenda
    titulo='Distribuição de Desempenho por Nível de Escolaridade do Pai',
    rotacao_xticks=45,
    rotacao_xticks_barra=90,
    pad_titulo=20,
    palette='Set2'
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8676\10489152.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)

# %%
# Plotando Infraestrutura e Nivel de Escolaridade dos Mãe
plot_histograma(
    df=microdados,
    coluna_x='Q002',
    coluna_hue='categoria_infraestrutura',
    dicionario_x=q001,                      # Mapeamento para rótulos do eixo x
    dicionario_hue=infra,   
                   order_hue=order_hue_infra,               # Não precisa mapear novamente
    titulo='Distribuição dos Infraestrutura por Nível de Escolaridade da Mãe',
    rotacao_xticks=45,
    pad_titulo=20,
    palette='Set2'
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13192\10489152.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)

# %%
# Plotando Desempenho por escolaridade do Mãe
plot_histograma(
    df=microdados,
    coluna_x='Q002',
    coluna_hue='NU_DESEMPENHO',
    dicionario_x=q001,                      # Mapeamento para rótulos do eixo x
    dicionario_hue=desempenho,  
              order_hue=order_hue_desempenho,          # Mapeamento para rótulos da legenda
    titulo='Distribuição de Desempenho por Nível de Escolaridade da Mãe',
    rotacao_xticks=45,
    rotacao_xticks_barra=90,
    pad_titulo=20,
    palette='Set2'
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8676\10489152.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)

# %%
# Plotando Desempenho por acesso a internet
plot_histograma(
    df=microdados,
    coluna_x='Q025',
    coluna_hue='NU_DESEMPENHO',
    dicionario_x=desempenho,                      # Mapeamento para rótulos do eixo x
    dicionario_hue=desempenho, 
    order_hue=order_hue_desempenho     ,      # Mapeamento para rótulos da legenda
    titulo='Distribuição de Desempenho por Acesso à Internet',
    rotacao_xticks=0,
    pad_titulo=20,
    palette='Set2'
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8676\10489152.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)

# %%
# Plotando Desempenho por pessoas na residencia
plot_histograma(
    df=microdados,
    coluna_x='Q005',
    coluna_hue='NU_DESEMPENHO',
    dicionario_x=q7_q19,                      # Mapeamento para rótulos do eixo x
    dicionario_hue=desempenho,
    order_hue=order_hue_desempenho,            # Mapeamento para rótulos da legenda
    titulo='Distribuição de Desempenho por Quantidade de Pessoas na Residência',
    rotacao_xticks=0,
    rotacao_xticks_barra=90,
    text_size=8,
    pad_titulo=20,
    palette='Set2'
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8676\10489152.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)

# %%
# Plotando infraestrutura por pessoas na residencia
plot_histograma(
    df=microdados,
    coluna_x='Q005',
    coluna_hue='categoria_infraestrutura',
    dicionario_x=q7_q19,                      # Mapeamento para rótulos do eixo x
    dicionario_hue=infra,
    order_hue=order_hue_infra,            # Mapeamento para rótulos da legenda
    titulo='Distribuição de Infraestrutura por Quantidade de Pessoas na Residência',
    rotacao_xticks=0,
    rotacao_xticks_barra=90,
    text_size=9,
    pad_titulo=20,
    palette='Set2'
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13192\10489152.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)

# %%
# Agrupando por sexo e calculando a média das notas
desempenho_sexo = microdados.groupby('TP_SEXO')[['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT']].median()
desempenho_sexo.index = desempenho_sexo.index.map({False: 'Feminino', True: 'Masculino'})

# Renomeando as colunas para tornar a legenda mais clara
desempenho_sexo.rename(columns={
    'NU_NOTA_CN': 'Ciências da Natureza',
    'NU_NOTA_CH': 'Ciências Humanas',
    'NU_NOTA_LC': 'Linguagens e Códigos',
    'NU_NOTA_MT': 'Matemática'
}, inplace=True)

# Plotando o desempenho por sexo com valores no topo das barras
ax = desempenho_sexo.plot(kind='bar', figsize=(10, 6))
plt.title('Desempenho Acadêmico por Sexo', fontsize=14)
plt.xlabel('Sexo', fontsize=12)
plt.ylabel('Nota Média', fontsize=12)
plt.xticks(rotation=0)

for p in ax.patches:
    ax.annotate(
        f'{p.get_height():.2f}',
        (p.get_x() + p.get_width() / 2, p.get_height()),
        ha='center',
        va='bottom',
        xytext=(0, 5),
        textcoords='offset points'
    )

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13192\735180488.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   desempenho_sexo = microdados.groupby('TP_SEXO')[['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT']].median()

# %%
# Agrupando por raça e calculando a média das notas
desempenho_raca = microdados.groupby('TP_COR_RACA')[['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT']].median()
desempenho_raca.index = desempenho_raca.index.map(cor_raca)

# Renomeando as colunas para tornar a legenda mais clara
desempenho_raca.rename(columns={
    'NU_NOTA_CN': 'Ciências da Natureza',
    'NU_NOTA_CH': 'Ciências Humanas',
    'NU_NOTA_LC': 'Linguagens e Códigos',
    'NU_NOTA_MT': 'Matemática'
}, inplace=True)

# Plotando o desempenho por raça com valores no topo das barras
fig, ax = plt.subplots(figsize=(10, 5))  # Reduzi o tamanho da figura

desempenho_raca.plot(kind='bar', ax=ax)

plt.title('Desempenho Acadêmico por Raça', fontsize=14)
plt.xlabel('Raça', fontsize=12)
plt.ylabel('Nota Média', fontsize=12)
plt.xticks(rotation=0)
plt.ylim(350, None)  # Define o limite inferior do eixo y em 300

# Movendo a legenda para fora do gráfico
plt.legend(title='Disciplinas', bbox_to_anchor=(1, 1), loc='upper left')

for p in ax.patches:
    ax.annotate(
        f'{p.get_height():.2f}',
        (p.get_x() + p.get_width() / 2, p.get_height()),
        ha='center',
        va='bottom',
        xytext=(0, 5),
        textcoords='offset points',
        rotation=90
    )

plt.tight_layout()
plt.show()

# %%
# Agrupando por escolaridade do pai e calculando a média das notas
desempenho_pai = microdados.groupby('Q001')[['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT']].median()
desempenho_pai.index = desempenho_pai.index.map(q001)

# Renomeando as colunas para tornar a legenda mais clara
desempenho_pai.rename(columns={
    'NU_NOTA_CN': 'Ciências da Natureza',
    'NU_NOTA_CH': 'Ciências Humanas',
    'NU_NOTA_LC': 'Linguagens e Códigos',
    'NU_NOTA_MT': 'Matemática'
}, inplace=True)

# Plotando o desempenho por escolaridade do pai com valores no topo das barras
fig, ax = plt.subplots(figsize=(10, 7))  # Reduzi o tamanho da figura

desempenho_pai.plot(kind='bar', ax=ax)

plt.title('Desempenho Acadêmico por Escolaridade do Pai', fontsize=14)
plt.xlabel('Escolaridade do Pai', fontsize=12)
plt.ylabel('Nota Média', fontsize=12)
plt.xticks(rotation=45)
plt.ylim(350, None)  # Define o limite inferior do eixo y em 350

for p in ax.patches:
    ax.annotate(
        f'{p.get_height():.2f}',
        (p.get_x() + p.get_width() / 2, p.get_height()),
        ha='center',
        va='bottom',
        xytext=(0, 5),
        textcoords='offset points',
        rotation=90
    )

# Movendo a legenda para fora do gráfico
plt.legend(title='Disciplinas', bbox_to_anchor=(1, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13192\3622023728.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   desempenho_pai = microdados.groupby('Q001')[['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT']].median()

# %%
# Agrupando por escolaridade da Mãe e calculando a média das notas
desempenho_pai = microdados.groupby('Q002')[['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT']].median()
desempenho_pai.index = desempenho_pai.index.map(q001)

# Renomeando as colunas para tornar a legenda mais clara
desempenho_pai.rename(columns={
    'NU_NOTA_CN': 'Ciências da Natureza',
    'NU_NOTA_CH': 'Ciências Humanas',
    'NU_NOTA_LC': 'Linguagens e Códigos',
    'NU_NOTA_MT': 'Matemática'
}, inplace=True)

# Plotando o desempenho por escolaridade da Mãe com valores no topo das barras
fig, ax = plt.subplots(figsize=(10, 7))  # Reduzi o tamanho da figura

desempenho_pai.plot(kind='bar', ax=ax)

plt.title('Desempenho Acadêmico por Escolaridade da Mãe', fontsize=14)
plt.xlabel('Escolaridade da Mãe', fontsize=12)
plt.ylabel('Nota Média', fontsize=12)
plt.xticks(rotation=45)
plt.ylim(350, None)  # Define o limite inferior do eixo y em 350

for p in ax.patches:
    ax.annotate(
        f'{p.get_height():.2f}',
        (p.get_x() + p.get_width() / 2, p.get_height()),
        ha='center',
        va='bottom',
        xytext=(0, 5),
        textcoords='offset points',
        rotation=90
    )

# Movendo a legenda para fora do gráfico
plt.legend(title='Disciplinas', bbox_to_anchor=(1, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13192\1656111575.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   desempenho_pai = microdados.groupby('Q002')[['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT']].median()
